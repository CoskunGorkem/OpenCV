# %% [markdown]
# ## This part of the tutorial includes some basics of opencv, such as reading and basic image altering methods

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Reading the image

# %%
image = cv2.imread('../images/dog.jpg')

# %% [markdown]
# ### Rotating the image

# %%
rotated_image = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)

# %% [markdown]
# ### Horizontal flip

# %%
flipped = cv2.flip(image, 1)

# %% [markdown]
# ### Scaling

# %%
image_scaled = cv2.resize(image, None, fx=0.15, fy=0.15)

# %% [markdown]
# ### Scaling v1

# %%
img_scaled_v1 = cv2.resize(image, None, fx=2, fy=2, interpolation = cv2.INTER_CUBIC)

# %% [markdown]
# ### Scaling v2

# %%
img_scaled_v2 = cv2.resize(image, (300, 300), interpolation = cv2.INTER_AREA)

# %%
row, col = 2, 3
fig, axs = plt.subplots(row, col, figsize=(15, 10))
fig.tight_layout()


axs[0][0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
axs[0][0].set_title('Original Image')


axs[0][1].imshow(cv2.cvtColor(flipped, cv2.COLOR_BGR2RGB))
axs[0][1].set_title('Horizontal Flipped')

axs[0][2].imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
axs[0][2].set_title('Rotated Image')


axs[1][0].imshow(cv2.cvtColor(image_scaled, cv2.COLOR_BGR2RGB))
axs[1][0].set_title('Scaling - Linear Interpolation')

axs[1][1].imshow(cv2.cvtColor(img_scaled_v1, cv2.COLOR_BGR2RGB))
axs[1][1].set_title('Scaling - INTER_CUBIC')

axs[1][2].imshow(cv2.cvtColor(img_scaled_v2, cv2.COLOR_BGR2RGB))
axs[1][2].set_title('Scaling - INTER_AREA')
# Out:
# Text(0.5, 1.0, 'Scaling - INTER_AREA')
