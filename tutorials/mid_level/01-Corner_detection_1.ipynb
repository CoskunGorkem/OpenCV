# %% [markdown]
# ### Corner Detection 1
#
#
# In this chapter,
#
# We will understand the concepts behind Harris Corner Detection.
# We will see the following function: cv2.cornerHarris()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('../images/chess.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Chess board')
plt.show()

# %% [markdown]
# ### Harris Corner Detection
#
# OpenCV has the function cv2.cornerHarris() for this purpose. Its arguments are:
#
# img - Input image. It should be grayscale and float32 type.
# blockSize - It is the size of neighbourhood considered for corner detection
# ksize - Aperture parameter of the Sobel derivative used.
# k - Harris detector free parameter in the equation.

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#Result is dilated 3 times for highlighting the corners, 
#That step is only for visualisation
dst = cv2.dilate(dst,None)
dst = cv2.dilate(dst,None)
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.

img[dst>0.01*dst.max()]=[0,0,255]
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Chess board with red dots on corners')
plt.show()
